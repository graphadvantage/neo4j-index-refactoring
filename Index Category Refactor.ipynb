# %%
#STEP 1 : Generate fake data using GraphAware graphgen
# https://github.com/graphaware/neo4j-graphgen-procedure
# you will need to compile the graphgen .jar file and add it to Neo4j/plugins and restart Neo4j
# (tip: update to JDK 8)

#!pip install neo4j-driver

import time

from neo4j.v1 import GraphDatabase, basic_auth, TRUST_ON_FIRST_USE, CypherError

driver = GraphDatabase.driver("bolt://localhost",
                              auth=basic_auth("neo4j", "neo4j"),
                              encrypted=False,
                              trust=TRUST_ON_FIRST_USE)

session = driver.session()


generate1 = 
'''
CALL generate.nodes('Organization', '{name: companyName, country: country}', 1000000)
'''

session = driver.session()
t0 = time.time()
print("processing...")
result = session.run(generate1)
summary = result.consume()
counters = summary.counters
print(summary)
print(counters)
print(round((time.time() - t0)*1000,1), " ms elapsed time")
print('-----------------')
session.close()

# %%
#STEP 2:  Set index on child property and constraint on parent category

#!pip install neo4j-driver

import time

from neo4j.v1 import GraphDatabase, basic_auth, TRUST_ON_FIRST_USE, CypherError

driver = GraphDatabase.driver("bolt://localhost",
                              auth=basic_auth("neo4j", "neo4j"),
                              encrypted=False,
                              trust=TRUST_ON_FIRST_USE)

session = driver.session()


index1 = '''
CREATE INDEX ON :Organization(country)
'''

constraint1 = '''
CREATE CONSTRAINT ON (n:Country) ASSERT n.countryName IS UNIQUE;
'''

session = driver.session()
t0 = time.time()
print("processing...")
result = session.run(index1)
summary = result.consume()
counters = summary.counters
print(summary)
print(counters)
print(round((time.time() - t0)*1000,1), " ms elapsed time")
print('-----------------')
session.close()


session = driver.session()
t0 = time.time()
print("processing...")
result = session.run(constraint1)
summary = result.consume()
counters = summary.counters
print(summary)
print(counters)
print(round((time.time() - t0)*1000,1), " ms elapsed time")
print('-----------------')
session.close()
# Out:
# processing...
# <neo4j.v1.session.ResultSummary object at 0x10936a8d0>
# {}
# 5.2  ms elapsed time
# -----------------
# processing...
# <neo4j.v1.session.ResultSummary object at 0x10936ab00>
# {'constraints_added': 1}
# 323.8  ms elapsed time
# -----------------

# %%
#STEP 4: (Optional)  Warmup Page Cache, helpful for large graphs
# requires APOC procedures
# https://neo4j-contrib.github.io/neo4j-apoc-procedures/

#!pip install neo4j-driver

import time

from neo4j.v1 import GraphDatabase, basic_auth, TRUST_ON_FIRST_USE, CypherError

driver = GraphDatabase.driver("bolt://localhost",
                              auth=basic_auth("neo4j", "neo4j"),
                              encrypted=False,
                              trust=TRUST_ON_FIRST_USE)

session = driver.session()


warmpup1 = '''
CALL apoc.warmup.run();
'''

t0 = time.time()
print("processing...")

result = session.run(warmup1)

for record in result:
    print("%s" % (record)) 

summary = result.consume()
counters = summary.counters
print(counters)

print(round((time.time() - t0)*1000,1), " ms elapsed time")
print('-----------------')

session.close()
# Out:
# processing...
# <Record pageSize=8192 nodesPerPage=546 nodesTotal=1000244 nodesLoaded=1831 nodesTime=0 relsPerPage=240 relsTotal=0 relsLoaded=0 relsTime=0 totalTime=0>
# {}
# 113.0  ms elapsed time
# -----------------

# %%
# STEP 5: Extract and create parent Category nodes

import time

from neo4j.v1 import GraphDatabase, basic_auth, TRUST_ON_FIRST_USE, CypherError

driver = GraphDatabase.driver("bolt://localhost",
                              auth=basic_auth("neo4j", "neo4j"),
                              encrypted=False,
                              trust=TRUST_ON_FIRST_USE)

session = driver.session()

cleanup1 = '''
MATCH (n:Country) DETACH DELETE n
'''

# extract from a 5% random sample
extractCategory1 = '''
MATCH (n:Organization) WHERE rand() < 0.05
WITH COLLECT(DISTINCT n.country) AS names
FOREACH (name IN names |
 MERGE (:Country {countryName: name}))
RETURN names
'''


# or extract from a full scan
extractCategory2 = '''
MATCH (n:Organization)
WITH COLLECT(DISTINCT n.country) AS names
FOREACH (name IN names |
 MERGE (:Country {countryName: name}))
RETURN names
'''


session = driver.session()
t0 = time.time()
print("processing...")
result = session.run(cleanup1)
summary = result.consume()
counters = summary.counters
print(summary)
print(counters)
print(round((time.time() - t0)*1000,1), " ms elapsed time")
print('-----------------')
session.close()


session = driver.session()
t0 = time.time()
print("processing...")
result = session.run(extractCategory1)
summary = result.consume()
counters = summary.counters
print(summary)
print(counters)
print(round((time.time() - t0)*1000,1), " ms elapsed time")
print('-----------------')
session.close()
# Out:
# processing...
# <neo4j.v1.session.ResultSummary object at 0x1093c9908>
# {'relationships_deleted': 1000000, 'nodes_deleted': 244}
# 16084.0  ms elapsed time
# -----------------
# processing...
# <neo4j.v1.session.ResultSummary object at 0x109374208>
# {'labels_added': 244, 'properties_set': 244, 'nodes_created': 244}
# 552.6  ms elapsed time
# -----------------

# %%
# Refactor Organizations to Country, computed batches

import time

from neo4j.v1 import GraphDatabase, basic_auth, TRUST_ON_FIRST_USE, CypherError

driver = GraphDatabase.driver("bolt://localhost",
                              auth=basic_auth("neo4j", "neo4j"),
                              encrypted=False,
                              trust=TRUST_ON_FIRST_USE)
session = driver.session()

childProps1 = '''
MATCH (n:Organization)
WHERE NOT ((n)-[:HAS_LOCATION]-())
RETURN n.country AS pname, count(n) AS ncount
'''

indexRefactor1 = '''
MATCH (c:Country {countryName:{pname}}), (n:Organization {country:{pname}})
WHERE NOT ((n)-[:HAS_LOCATION]-())
WITH c,n LIMIT {limit} MERGE (c)<-[r:HAS_LOCATION]-(n)
'''
ntotal = 0
batchSize = 2000

try:
    tjob = time.time()
    print("processing query1 ---> getting child property list for refactoring")
    
    propertyList = session.run(childProps1)
    
    print('-----------------')
    print("processing query2 ---> starting refactoring to parent category")
    print ("%s %s" % ("using batch size: ", batchSize))
    print('-----------------')
 
    for property in propertyList:
        print("%s %s %s" % (property["pname"], "nodes:", property["ncount"]))
        t0 = time.time()
        pname = (property["pname"])
        ncount = (property["ncount"])
        
        batch = 0
        batches = 0
        
        batches = int(ncount/batchSize)+1
        
        for batch in range(batches):
            
            print("%s %s %s %s" % ("batch: ", batch+1 , " of ", batches))
        
            while True:
                result = session.run(indexRefactor1, {"pname": pname, "limit": batchSize})
                lresult=list(result)
                summary = result.consume()
                counters = summary.counters
                print(counters)
            
                if len(lresult) > 0:
                    print('--next batch--')
                else:
                    break
                    print('-----done-----')
                    
        print(round((time.time() - t0)*1000,1), " ms elapsed time")
        ntotal = ntotal + ncount
        print ("%s %s" % ("------------------------------> total refactored nodes: ", ntotal))
        
                
except Exception as e:
    print('*** Got exception',e)
    if not isinstance(e, CypherError):
        print('*** Rolling back')
        session.rollback()
    else:
        print('*** Not rolling back')
    
finally:
    print('Done!')
    print(round((time.time() - tjob)/60,1), " minutes elapsed time")
# Out:
# processing query1 ---> getting child property list for refactoring
# -----------------
# processing query2 ---> starting refactoring to parent category
# using batch size:  2000
# -----------------
# Azerbaijan nodes: 3985
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1985}
# 120.4  ms elapsed time
# ------------------------------> total refactored nodes:  3985
# Saint Kitts and Nevis nodes: 4161
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 161}
# 126.9  ms elapsed time
# ------------------------------> total refactored nodes:  8146
# Egypt nodes: 3980
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1980}
# 122.5  ms elapsed time
# ------------------------------> total refactored nodes:  12126
# Saudi Arabia nodes: 4131
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 131}
# 142.0  ms elapsed time
# ------------------------------> total refactored nodes:  16257
# Virgin Islands, U.S. nodes: 3977
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1977}
# 241.3  ms elapsed time
# ------------------------------> total refactored nodes:  20234
# Bouvet Island (Bouvetoya) nodes: 4029
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 29}
# 278.6  ms elapsed time
# ------------------------------> total refactored nodes:  24263
# Turkmenistan nodes: 3899
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1899}
# 180.6  ms elapsed time
# ------------------------------> total refactored nodes:  28162
# Christmas Island nodes: 3968
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1968}
# 133.0  ms elapsed time
# ------------------------------> total refactored nodes:  32130
# Brazil nodes: 4002
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 2}
# 144.3  ms elapsed time
# ------------------------------> total refactored nodes:  36132
# Senegal nodes: 4067
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 67}
# 142.4  ms elapsed time
# ------------------------------> total refactored nodes:  40199
# Kuwait nodes: 4117
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 117}
# 142.6  ms elapsed time
# ------------------------------> total refactored nodes:  44316
# Austria nodes: 4052
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 52}
# 142.4  ms elapsed time
# ------------------------------> total refactored nodes:  48368
# South Africa nodes: 4124
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 124}
# 145.7  ms elapsed time
# ------------------------------> total refactored nodes:  52492
# Vietnam nodes: 4089
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 89}
# 147.6  ms elapsed time
# ------------------------------> total refactored nodes:  56581
# Canada nodes: 4112
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 112}
# 127.1  ms elapsed time
# ------------------------------> total refactored nodes:  60693
# Tokelau nodes: 4087
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 87}
# 141.3  ms elapsed time
# ------------------------------> total refactored nodes:  64780
# Niue nodes: 4039
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 39}
# 165.2  ms elapsed time
# ------------------------------> total refactored nodes:  68819
# Afghanistan nodes: 4151
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 151}
# 149.3  ms elapsed time
# ------------------------------> total refactored nodes:  72970
# Saint Pierre and Miquelon nodes: 4007
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 7}
# 155.5  ms elapsed time
# ------------------------------> total refactored nodes:  76977
# Eritrea nodes: 4202
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 202}
# 143.3  ms elapsed time
# ------------------------------> total refactored nodes:  81179
# Western Sahara nodes: 4001
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 1}
# 152.3  ms elapsed time
# ------------------------------> total refactored nodes:  85180
# Lao People's Democratic Republic nodes: 4066
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 66}
# 189.8  ms elapsed time
# ------------------------------> total refactored nodes:  89246
# Switzerland nodes: 4042
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 42}
# 243.7  ms elapsed time
# ------------------------------> total refactored nodes:  93288
# Qatar nodes: 4086
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 86}
# 337.7  ms elapsed time
# ------------------------------> total refactored nodes:  97374
# Slovenia nodes: 4141
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 141}
# 227.9  ms elapsed time
# ------------------------------> total refactored nodes:  101515
# Taiwan nodes: 4003
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 3}
# 230.2  ms elapsed time
# ------------------------------> total refactored nodes:  105518
# Australia nodes: 3987
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1987}
# 131.1  ms elapsed time
# ------------------------------> total refactored nodes:  109505
# Svalbard & Jan Mayen Islands nodes: 4147
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 147}
# 153.5  ms elapsed time
# ------------------------------> total refactored nodes:  113652
# Sao Tome and Principe nodes: 4022
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 22}
# 141.2  ms elapsed time
# ------------------------------> total refactored nodes:  117674
# Mongolia nodes: 4074
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 74}
# 139.0  ms elapsed time
# ------------------------------> total refactored nodes:  121748
# Reunion nodes: 3942
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1942}
# 137.5  ms elapsed time
# ------------------------------> total refactored nodes:  125690
# Belarus nodes: 3994
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1994}
# 133.3  ms elapsed time
# ------------------------------> total refactored nodes:  129684
# Central African Republic nodes: 4080
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 80}
# 149.8  ms elapsed time
# ------------------------------> total refactored nodes:  133764
# Gibraltar nodes: 4106
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 106}
# 138.1  ms elapsed time
# ------------------------------> total refactored nodes:  137870
# Uganda nodes: 4158
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 158}
# 128.4  ms elapsed time
# ------------------------------> total refactored nodes:  142028
# Comoros nodes: 4148
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 148}
# 150.7  ms elapsed time
# ------------------------------> total refactored nodes:  146176
# Tanzania nodes: 4116
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 116}
# 152.8  ms elapsed time
# ------------------------------> total refactored nodes:  150292
# Macedonia nodes: 4122
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 122}
# 207.8  ms elapsed time
# ------------------------------> total refactored nodes:  154414
# Panama nodes: 4075
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 75}
# 139.5  ms elapsed time
# ------------------------------> total refactored nodes:  158489
# Republic of Korea nodes: 4097
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 97}
# 140.9  ms elapsed time
# ------------------------------> total refactored nodes:  162586
# Pitcairn Islands nodes: 4123
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 123}
# 143.3  ms elapsed time
# ------------------------------> total refactored nodes:  166709
# Costa Rica nodes: 4117
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 117}
# 149.0  ms elapsed time
# ------------------------------> total refactored nodes:  170826
# Luxembourg nodes: 4255
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 255}
# 151.0  ms elapsed time
# ------------------------------> total refactored nodes:  175081
# Belgium nodes: 4109
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 109}
# 146.1  ms elapsed time
# ------------------------------> total refactored nodes:  179190
# French Guiana nodes: 4102
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 102}
# 154.9  ms elapsed time
# ------------------------------> total refactored nodes:  183292
# French Polynesia nodes: 4146
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 146}
# 138.5  ms elapsed time
# ------------------------------> total refactored nodes:  187438
# Norfolk Island nodes: 4131
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 131}
# 135.6  ms elapsed time
# ------------------------------> total refactored nodes:  191569
# Timor-Leste nodes: 4013
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 13}
# 144.0  ms elapsed time
# ------------------------------> total refactored nodes:  195582
# Heard Island and McDonald Islands nodes: 4049
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 49}
# 144.3  ms elapsed time
# ------------------------------> total refactored nodes:  199631
# Romania nodes: 4159
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 159}
# 136.1  ms elapsed time
# ------------------------------> total refactored nodes:  203790
# Brunei Darussalam nodes: 4033
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 33}
# 149.8  ms elapsed time
# ------------------------------> total refactored nodes:  207823
# Saint Helena nodes: 4096
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 96}
# 169.7  ms elapsed time
# ------------------------------> total refactored nodes:  211919
# Tunisia nodes: 4097
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 97}
# 147.4  ms elapsed time
# ------------------------------> total refactored nodes:  216016
# Niger nodes: 4068
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 68}
# 133.7  ms elapsed time
# ------------------------------> total refactored nodes:  220084
# Morocco nodes: 4081
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 81}
# 151.6  ms elapsed time
# ------------------------------> total refactored nodes:  224165
# Mauritius nodes: 4113
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 113}
# 158.4  ms elapsed time
# ------------------------------> total refactored nodes:  228278
# Congo nodes: 8309
# batch:  1  of  5
# {'relationships_created': 2000}
# batch:  2  of  5
# {'relationships_created': 2000}
# batch:  3  of  5
# {'relationships_created': 2000}
# batch:  4  of  5
# {'relationships_created': 2000}
# batch:  5  of  5
# {'relationships_created': 309}
# 201.2  ms elapsed time
# ------------------------------> total refactored nodes:  236587
# Gambia nodes: 4125
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 125}
# 129.4  ms elapsed time
# ------------------------------> total refactored nodes:  240712
# Guam nodes: 4115
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 115}
# 134.4  ms elapsed time
# ------------------------------> total refactored nodes:  244827
# Thailand nodes: 4113
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 113}
# 131.9  ms elapsed time
# ------------------------------> total refactored nodes:  248940
# Ghana nodes: 4099
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 99}
# 134.9  ms elapsed time
# ------------------------------> total refactored nodes:  253039
# Monaco nodes: 3984
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1984}
# 120.5  ms elapsed time
# ------------------------------> total refactored nodes:  257023
# Argentina nodes: 4058
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 58}
# 134.3  ms elapsed time
# ------------------------------> total refactored nodes:  261081
# Faroe Islands nodes: 4187
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 187}
# 133.5  ms elapsed time
# ------------------------------> total refactored nodes:  265268
# Solomon Islands nodes: 4058
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 58}
# 141.0  ms elapsed time
# ------------------------------> total refactored nodes:  269326
# Aruba nodes: 4159
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 159}
# 150.4  ms elapsed time
# ------------------------------> total refactored nodes:  273485
# Malawi nodes: 4087
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 87}
# 152.6  ms elapsed time
# ------------------------------> total refactored nodes:  277572
# Sudan nodes: 4155
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 155}
# 158.3  ms elapsed time
# ------------------------------> total refactored nodes:  281727
# Saint Martin nodes: 4033
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 33}
# 146.2  ms elapsed time
# ------------------------------> total refactored nodes:  285760
# Papua New Guinea nodes: 4188
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 188}
# 139.1  ms elapsed time
# ------------------------------> total refactored nodes:  289948
# Lesotho nodes: 4040
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 40}
# 129.2  ms elapsed time
# ------------------------------> total refactored nodes:  293988
# Mali nodes: 4088
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 88}
# 157.8  ms elapsed time
# ------------------------------> total refactored nodes:  298076
# Antarctica (the territory South of 60 deg S) nodes: 4032
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 32}
# 159.8  ms elapsed time
# ------------------------------> total refactored nodes:  302108
# Tonga nodes: 4096
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 96}
# 153.7  ms elapsed time
# ------------------------------> total refactored nodes:  306204
# Saint Barthelemy nodes: 3992
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1992}
# 159.5  ms elapsed time
# ------------------------------> total refactored nodes:  310196
# Dominica nodes: 4053
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 53}
# 148.4  ms elapsed time
# ------------------------------> total refactored nodes:  314249
# Cape Verde nodes: 4114
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 114}
# 138.6  ms elapsed time
# ------------------------------> total refactored nodes:  318363
# Peru nodes: 3994
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1994}
# 138.0  ms elapsed time
# ------------------------------> total refactored nodes:  322357
# Honduras nodes: 4099
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 99}
# 162.2  ms elapsed time
# ------------------------------> total refactored nodes:  326456
# Virgin Islands, British nodes: 4014
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 14}
# 144.1  ms elapsed time
# ------------------------------> total refactored nodes:  330470
# Zimbabwe nodes: 4118
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 118}
# 138.9  ms elapsed time
# ------------------------------> total refactored nodes:  334588
# Syrian Arab Republic nodes: 4083
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 83}
# 147.3  ms elapsed time
# ------------------------------> total refactored nodes:  338671
# Myanmar nodes: 4063
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 63}
# 136.4  ms elapsed time
# ------------------------------> total refactored nodes:  342734
# Kiribati nodes: 4079
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 79}
# 134.6  ms elapsed time
# ------------------------------> total refactored nodes:  346813
# Maldives nodes: 4028
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 28}
# 134.8  ms elapsed time
# ------------------------------> total refactored nodes:  350841
# Seychelles nodes: 4191
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 191}
# 150.2  ms elapsed time
# ------------------------------> total refactored nodes:  355032
# Vanuatu nodes: 4126
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 126}
# 148.0  ms elapsed time
# ------------------------------> total refactored nodes:  359158
# Yemen nodes: 4103
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 103}
# 151.9  ms elapsed time
# ------------------------------> total refactored nodes:  363261
# Bahamas nodes: 4070
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 70}
# 147.4  ms elapsed time
# ------------------------------> total refactored nodes:  367331
# Norway nodes: 4120
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 120}
# 148.1  ms elapsed time
# ------------------------------> total refactored nodes:  371451
# Guadeloupe nodes: 4098
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 98}
# 139.3  ms elapsed time
# ------------------------------> total refactored nodes:  375549
# Montserrat nodes: 4062
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 62}
# 151.8  ms elapsed time
# ------------------------------> total refactored nodes:  379611
# United States Minor Outlying Islands nodes: 4143
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 143}
# 144.0  ms elapsed time
# ------------------------------> total refactored nodes:  383754
# Greenland nodes: 4103
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 103}
# 145.3  ms elapsed time
# ------------------------------> total refactored nodes:  387857
# Madagascar nodes: 4040
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 40}
# 147.4  ms elapsed time
# ------------------------------> total refactored nodes:  391897
# Guatemala nodes: 4202
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 202}
# 149.1  ms elapsed time
# ------------------------------> total refactored nodes:  396099
# San Marino nodes: 4004
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 4}
# 145.2  ms elapsed time
# ------------------------------> total refactored nodes:  400103
# Malta nodes: 3947
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1947}
# 134.4  ms elapsed time
# ------------------------------> total refactored nodes:  404050
# Nigeria nodes: 4110
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 110}
# 140.3  ms elapsed time
# ------------------------------> total refactored nodes:  408160
# Germany nodes: 4153
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 153}
# 137.3  ms elapsed time
# ------------------------------> total refactored nodes:  412313
# France nodes: 4187
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 187}
# 156.8  ms elapsed time
# ------------------------------> total refactored nodes:  416500
# New Caledonia nodes: 4109
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 109}
# 187.7  ms elapsed time
# ------------------------------> total refactored nodes:  420609
# Ireland nodes: 3953
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1953}
# 142.4  ms elapsed time
# ------------------------------> total refactored nodes:  424562
# Northern Mariana Islands nodes: 4114
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 114}
# 146.5  ms elapsed time
# ------------------------------> total refactored nodes:  428676
# Cyprus nodes: 4073
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 73}
# 148.2  ms elapsed time
# ------------------------------> total refactored nodes:  432749
# Italy nodes: 4082
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 82}
# 147.6  ms elapsed time
# ------------------------------> total refactored nodes:  436831
# Venezuela nodes: 4141
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 141}
# 154.9  ms elapsed time
# ------------------------------> total refactored nodes:  440972
# Kenya nodes: 4149
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 149}
# 150.1  ms elapsed time
# ------------------------------> total refactored nodes:  445121
# Pakistan nodes: 3954
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1954}
# 129.9  ms elapsed time
# ------------------------------> total refactored nodes:  449075
# Netherlands Antilles nodes: 4166
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 166}
# 145.5  ms elapsed time
# ------------------------------> total refactored nodes:  453241
# Bhutan nodes: 4080
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 80}
# 157.4  ms elapsed time
# ------------------------------> total refactored nodes:  457321
# Bangladesh nodes: 4097
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 97}
# 136.0  ms elapsed time
# ------------------------------> total refactored nodes:  461418
# Czech Republic nodes: 3961
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1961}
# 136.2  ms elapsed time
# ------------------------------> total refactored nodes:  465379
# Palau nodes: 4037
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 37}
# 141.6  ms elapsed time
# ------------------------------> total refactored nodes:  469416
# Benin nodes: 4026
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 26}
# 136.1  ms elapsed time
# ------------------------------> total refactored nodes:  473442
# Marshall Islands nodes: 4009
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 9}
# 138.9  ms elapsed time
# ------------------------------> total refactored nodes:  477451
# Falkland Islands (Malvinas) nodes: 4071
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 71}
# 131.4  ms elapsed time
# ------------------------------> total refactored nodes:  481522
# Martinique nodes: 4117
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 117}
# 145.3  ms elapsed time
# ------------------------------> total refactored nodes:  485639
# Democratic People's Republic of Korea nodes: 3924
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1924}
# 118.2  ms elapsed time
# ------------------------------> total refactored nodes:  489563
# Poland nodes: 4135
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 135}
# 126.5  ms elapsed time
# ------------------------------> total refactored nodes:  493698
# Holy See (Vatican City State) nodes: 3964
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1964}
# 124.3  ms elapsed time
# ------------------------------> total refactored nodes:  497662
# Estonia nodes: 4061
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 61}
# 133.9  ms elapsed time
# ------------------------------> total refactored nodes:  501723
# Uruguay nodes: 4126
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 126}
# 144.0  ms elapsed time
# ------------------------------> total refactored nodes:  505849
# Burundi nodes: 4199
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 199}
# 132.9  ms elapsed time
# ------------------------------> total refactored nodes:  510048
# Ecuador nodes: 4160
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 160}
# 140.2  ms elapsed time
# ------------------------------> total refactored nodes:  514208
# Ukraine nodes: 4111
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 111}
# 127.2  ms elapsed time
# ------------------------------> total refactored nodes:  518319
# Cayman Islands nodes: 4041
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 41}
# 134.1  ms elapsed time
# ------------------------------> total refactored nodes:  522360
# Haiti nodes: 4106
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 106}
# 129.6  ms elapsed time
# ------------------------------> total refactored nodes:  526466
# Dominican Republic nodes: 4127
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 127}
# 128.9  ms elapsed time
# ------------------------------> total refactored nodes:  530593
# Denmark nodes: 4120
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 120}
# 128.3  ms elapsed time
# ------------------------------> total refactored nodes:  534713
# Guinea-Bissau nodes: 4077
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 77}
# 128.0  ms elapsed time
# ------------------------------> total refactored nodes:  538790
# Saint Lucia nodes: 4012
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 12}
# 140.9  ms elapsed time
# ------------------------------> total refactored nodes:  542802
# Sri Lanka nodes: 4025
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 25}
# 128.2  ms elapsed time
# ------------------------------> total refactored nodes:  546827
# Guernsey nodes: 4007
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 7}
# 139.3  ms elapsed time
# ------------------------------> total refactored nodes:  550834
# China nodes: 4188
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 188}
# 136.0  ms elapsed time
# ------------------------------> total refactored nodes:  555022
# South Georgia and the South Sandwich Islands nodes: 4175
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 175}
# 129.5  ms elapsed time
# ------------------------------> total refactored nodes:  559197
# Isle of Man nodes: 4123
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 123}
# 126.8  ms elapsed time
# ------------------------------> total refactored nodes:  563320
# Zambia nodes: 4012
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 12}
# 128.7  ms elapsed time
# ------------------------------> total refactored nodes:  567332
# Grenada nodes: 4146
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 146}
# 130.6  ms elapsed time
# ------------------------------> total refactored nodes:  571478
# Puerto Rico nodes: 4187
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 187}
# 173.0  ms elapsed time
# ------------------------------> total refactored nodes:  575665
# Kazakhstan nodes: 4103
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 103}
# 140.4  ms elapsed time
# ------------------------------> total refactored nodes:  579768
# Turks and Caicos Islands nodes: 4059
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 59}
# 131.7  ms elapsed time
# ------------------------------> total refactored nodes:  583827
# Liberia nodes: 4091
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 91}
# 131.4  ms elapsed time
# ------------------------------> total refactored nodes:  587918
# El Salvador nodes: 4161
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 161}
# 135.3  ms elapsed time
# ------------------------------> total refactored nodes:  592079
# Bahrain nodes: 3983
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1983}
# 126.8  ms elapsed time
# ------------------------------> total refactored nodes:  596062
# Suriname nodes: 3973
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1973}
# 127.2  ms elapsed time
# ------------------------------> total refactored nodes:  600035
# Greece nodes: 4064
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 64}
# 143.9  ms elapsed time
# ------------------------------> total refactored nodes:  604099
# Liechtenstein nodes: 4097
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 97}
# 128.7  ms elapsed time
# ------------------------------> total refactored nodes:  608196
# Portugal nodes: 4026
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 26}
# 126.0  ms elapsed time
# ------------------------------> total refactored nodes:  612222
# Bosnia and Herzegovina nodes: 4127
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 127}
# 128.2  ms elapsed time
# ------------------------------> total refactored nodes:  616349
# Bulgaria nodes: 4078
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 78}
# 128.5  ms elapsed time
# ------------------------------> total refactored nodes:  620427
# Somalia nodes: 4193
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 193}
# 128.8  ms elapsed time
# ------------------------------> total refactored nodes:  624620
# Sweden nodes: 4108
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 108}
# 141.4  ms elapsed time
# ------------------------------> total refactored nodes:  628728
# Iceland nodes: 4072
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 72}
# 127.4  ms elapsed time
# ------------------------------> total refactored nodes:  632800
# United Arab Emirates nodes: 4087
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 87}
# 138.8  ms elapsed time
# ------------------------------> total refactored nodes:  636887
# Netherlands nodes: 4096
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 96}
# 130.9  ms elapsed time
# ------------------------------> total refactored nodes:  640983
# Ethiopia nodes: 4110
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 110}
# 132.5  ms elapsed time
# ------------------------------> total refactored nodes:  645093
# Philippines nodes: 4105
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 105}
# 132.5  ms elapsed time
# ------------------------------> total refactored nodes:  649198
# Colombia nodes: 4054
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 54}
# 133.8  ms elapsed time
# ------------------------------> total refactored nodes:  653252
# Oman nodes: 4034
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 34}
# 133.9  ms elapsed time
# ------------------------------> total refactored nodes:  657286
# Swaziland nodes: 4030
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 30}
# 128.3  ms elapsed time
# ------------------------------> total refactored nodes:  661316
# Turkey nodes: 4181
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 181}
# 127.8  ms elapsed time
# ------------------------------> total refactored nodes:  665497
# British Indian Ocean Territory (Chagos Archipelago) nodes: 4073
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 73}
# 134.1  ms elapsed time
# ------------------------------> total refactored nodes:  669570
# Samoa nodes: 4145
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 145}
# 137.7  ms elapsed time
# ------------------------------> total refactored nodes:  673715
# Wallis and Futuna nodes: 4076
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 76}
# 128.8  ms elapsed time
# ------------------------------> total refactored nodes:  677791
# Lithuania nodes: 4088
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 88}
# 131.6  ms elapsed time
# ------------------------------> total refactored nodes:  681879
# Trinidad and Tobago nodes: 4079
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 79}
# 138.8  ms elapsed time
# ------------------------------> total refactored nodes:  685958
# India nodes: 4094
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 94}
# 142.3  ms elapsed time
# ------------------------------> total refactored nodes:  690052
# Anguilla nodes: 4067
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 67}
# 127.8  ms elapsed time
# ------------------------------> total refactored nodes:  694119
# Libyan Arab Jamahiriya nodes: 4053
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 53}
# 152.1  ms elapsed time
# ------------------------------> total refactored nodes:  698172
# Djibouti nodes: 4085
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 85}
# 128.7  ms elapsed time
# ------------------------------> total refactored nodes:  702257
# Nepal nodes: 4034
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 34}
# 129.6  ms elapsed time
# ------------------------------> total refactored nodes:  706291
# French Southern Territories nodes: 4088
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 88}
# 126.3  ms elapsed time
# ------------------------------> total refactored nodes:  710379
# Cook Islands nodes: 3897
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1897}
# 119.3  ms elapsed time
# ------------------------------> total refactored nodes:  714276
# Latvia nodes: 4088
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 88}
# 128.8  ms elapsed time
# ------------------------------> total refactored nodes:  718364
# Hungary nodes: 4041
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 41}
# 130.6  ms elapsed time
# ------------------------------> total refactored nodes:  722405
# Antigua and Barbuda nodes: 4038
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 38}
# 127.8  ms elapsed time
# ------------------------------> total refactored nodes:  726443
# Chad nodes: 4185
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 185}
# 133.3  ms elapsed time
# ------------------------------> total refactored nodes:  730628
# Algeria nodes: 4218
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 218}
# 128.6  ms elapsed time
# ------------------------------> total refactored nodes:  734846
# Jordan nodes: 4135
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 135}
# 129.1  ms elapsed time
# ------------------------------> total refactored nodes:  738981
# Gabon nodes: 4035
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 35}
# 133.0  ms elapsed time
# ------------------------------> total refactored nodes:  743016
# Paraguay nodes: 4179
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 179}
# 134.8  ms elapsed time
# ------------------------------> total refactored nodes:  747195
# Lebanon nodes: 4071
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 71}
# 133.9  ms elapsed time
# ------------------------------> total refactored nodes:  751266
# Togo nodes: 4111
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 111}
# 133.3  ms elapsed time
# ------------------------------> total refactored nodes:  755377
# Fiji nodes: 4229
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 229}
# 127.0  ms elapsed time
# ------------------------------> total refactored nodes:  759606
# Russian Federation nodes: 4162
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 162}
# 128.9  ms elapsed time
# ------------------------------> total refactored nodes:  763768
# Sierra Leone nodes: 4024
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 24}
# 129.5  ms elapsed time
# ------------------------------> total refactored nodes:  767792
# Mauritania nodes: 4059
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 59}
# 135.6  ms elapsed time
# ------------------------------> total refactored nodes:  771851
# Macao nodes: 3997
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1997}
# 123.1  ms elapsed time
# ------------------------------> total refactored nodes:  775848
# American Samoa nodes: 4100
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 100}
# 129.2  ms elapsed time
# ------------------------------> total refactored nodes:  779948
# Slovakia (Slovak Republic) nodes: 4030
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 30}
# 142.9  ms elapsed time
# ------------------------------> total refactored nodes:  783978
# Uzbekistan nodes: 4107
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 107}
# 128.4  ms elapsed time
# ------------------------------> total refactored nodes:  788085
# Guyana nodes: 4013
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 13}
# 155.7  ms elapsed time
# ------------------------------> total refactored nodes:  792098
# Saint Vincent and the Grenadines nodes: 3989
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1989}
# 137.8  ms elapsed time
# ------------------------------> total refactored nodes:  796087
# Tuvalu nodes: 4171
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 171}
# 139.2  ms elapsed time
# ------------------------------> total refactored nodes:  800258
# Nauru nodes: 4005
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 5}
# 134.0  ms elapsed time
# ------------------------------> total refactored nodes:  804263
# Spain nodes: 3941
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1941}
# 122.8  ms elapsed time
# ------------------------------> total refactored nodes:  808204
# Albania nodes: 4094
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 94}
# 129.1  ms elapsed time
# ------------------------------> total refactored nodes:  812298
# Namibia nodes: 4059
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 59}
# 132.4  ms elapsed time
# ------------------------------> total refactored nodes:  816357
# Mexico nodes: 4146
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 146}
# 129.2  ms elapsed time
# ------------------------------> total refactored nodes:  820503
# Serbia nodes: 4007
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 7}
# 128.5  ms elapsed time
# ------------------------------> total refactored nodes:  824510
# Cameroon nodes: 4104
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 104}
# 121.9  ms elapsed time
# ------------------------------> total refactored nodes:  828614
# Iraq nodes: 3975
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1975}
# 127.5  ms elapsed time
# ------------------------------> total refactored nodes:  832589
# Guinea nodes: 3973
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1973}
# 119.6  ms elapsed time
# ------------------------------> total refactored nodes:  836562
# New Zealand nodes: 4032
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 32}
# 133.7  ms elapsed time
# ------------------------------> total refactored nodes:  840594
# Chile nodes: 4087
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 87}
# 138.7  ms elapsed time
# ------------------------------> total refactored nodes:  844681
# Belize nodes: 4189
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 189}
# 134.8  ms elapsed time
# ------------------------------> total refactored nodes:  848870
# Armenia nodes: 4142
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 142}
# 132.5  ms elapsed time
# ------------------------------> total refactored nodes:  853012
# Botswana nodes: 4074
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 74}
# 135.7  ms elapsed time
# ------------------------------> total refactored nodes:  857086
# Israel nodes: 4129
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 129}
# 136.7  ms elapsed time
# ------------------------------> total refactored nodes:  861215
# Croatia nodes: 4031
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 31}
# 135.9  ms elapsed time
# ------------------------------> total refactored nodes:  865246
# Hong Kong nodes: 4159
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 159}
# 134.6  ms elapsed time
# ------------------------------> total refactored nodes:  869405
# United States of America nodes: 4122
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 122}
# 127.0  ms elapsed time
# ------------------------------> total refactored nodes:  873527
# Cocos (Keeling) Islands nodes: 3977
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1977}
# 156.7  ms elapsed time
# ------------------------------> total refactored nodes:  877504
# Cuba nodes: 4046
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 46}
# 130.9  ms elapsed time
# ------------------------------> total refactored nodes:  881550
# Rwanda nodes: 4023
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 23}
# 145.9  ms elapsed time
# ------------------------------> total refactored nodes:  885573
# Malaysia nodes: 4099
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 99}
# 131.7  ms elapsed time
# ------------------------------> total refactored nodes:  889672
# United Kingdom nodes: 4061
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 61}
# 149.1  ms elapsed time
# ------------------------------> total refactored nodes:  893733
# Jersey nodes: 4099
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 99}
# 131.7  ms elapsed time
# ------------------------------> total refactored nodes:  897832
# Singapore nodes: 4085
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 85}
# 132.9  ms elapsed time
# ------------------------------> total refactored nodes:  901917
# Burkina Faso nodes: 4106
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 106}
# 131.3  ms elapsed time
# ------------------------------> total refactored nodes:  906023
# Cambodia nodes: 4119
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 119}
# 132.2  ms elapsed time
# ------------------------------> total refactored nodes:  910142
# Equatorial Guinea nodes: 4080
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 80}
# 129.0  ms elapsed time
# ------------------------------> total refactored nodes:  914222
# Mozambique nodes: 4015
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 15}
# 124.2  ms elapsed time
# ------------------------------> total refactored nodes:  918237
# Bermuda nodes: 4122
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 122}
# 144.2  ms elapsed time
# ------------------------------> total refactored nodes:  922359
# Palestinian Territory nodes: 4018
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 18}
# 130.0  ms elapsed time
# ------------------------------> total refactored nodes:  926377
# Montenegro nodes: 4051
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 51}
# 129.0  ms elapsed time
# ------------------------------> total refactored nodes:  930428
# Georgia nodes: 4105
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 105}
# 131.0  ms elapsed time
# ------------------------------> total refactored nodes:  934533
# Japan nodes: 4077
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 77}
# 134.5  ms elapsed time
# ------------------------------> total refactored nodes:  938610
# Kyrgyz Republic nodes: 4198
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 198}
# 126.7  ms elapsed time
# ------------------------------> total refactored nodes:  942808
# Mayotte nodes: 3978
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1978}
# 121.1  ms elapsed time
# ------------------------------> total refactored nodes:  946786
# Finland nodes: 4122
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 122}
# 122.6  ms elapsed time
# ------------------------------> total refactored nodes:  950908
# Cote d'Ivoire nodes: 4171
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 171}
# 139.9  ms elapsed time
# ------------------------------> total refactored nodes:  955079
# Moldova nodes: 4114
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 114}
# 123.0  ms elapsed time
# ------------------------------> total refactored nodes:  959193
# Tajikistan nodes: 4123
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 123}
# 126.8  ms elapsed time
# ------------------------------> total refactored nodes:  963316
# Andorra nodes: 4099
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 99}
# 124.5  ms elapsed time
# ------------------------------> total refactored nodes:  967415
# Nicaragua nodes: 4091
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 91}
# 130.3  ms elapsed time
# ------------------------------> total refactored nodes:  971506
# Barbados nodes: 4124
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 124}
# 128.7  ms elapsed time
# ------------------------------> total refactored nodes:  975630
# Micronesia nodes: 4063
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 63}
# 145.6  ms elapsed time
# ------------------------------> total refactored nodes:  979693
# Indonesia nodes: 4031
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 31}
# 126.3  ms elapsed time
# ------------------------------> total refactored nodes:  983724
# Jamaica nodes: 4197
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 197}
# 129.8  ms elapsed time
# ------------------------------> total refactored nodes:  987921
# Iran nodes: 3963
# batch:  1  of  2
# {'relationships_created': 2000}
# batch:  2  of  2
# {'relationships_created': 1963}
# 120.7  ms elapsed time
# ------------------------------> total refactored nodes:  991884
# Bolivia nodes: 4076
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 76}
# 127.8  ms elapsed time
# ------------------------------> total refactored nodes:  995960
# Angola nodes: 4040
# batch:  1  of  3
# {'relationships_created': 2000}
# batch:  2  of  3
# {'relationships_created': 2000}
# batch:  3  of  3
# {'relationships_created': 40}
# 129.0  ms elapsed time
# ------------------------------> total refactored nodes:  1000000
# Done!
# 0.6  minutes elapsed time

# %%
# Refactor Organizations to Country, implicit batches

import time

from neo4j.v1 import GraphDatabase, basic_auth, TRUST_ON_FIRST_USE, CypherError

driver = GraphDatabase.driver("bolt://localhost",
                              auth=basic_auth("neo4j", "neo4j"),
                              encrypted=False,
                              trust=TRUST_ON_FIRST_USE)
session = driver.session()

childProps1 = '''
MATCH (n:Organization)
WHERE NOT ((n)-[:HAS_LOCATION]-())
RETURN n.country AS pname, count(n) AS ncount
'''

indexRefactor1 = '''
MATCH (c:Country {countryName:{pname}}), (n:Organization {country:{pname}})
WHERE NOT ((n)-[:HAS_LOCATION]-())
WITH c,n LIMIT {limit} MERGE (c)<-[r:HAS_LOCATION]-(n)
'''
ntotal = 0
batchSize = 2000


try:
    tjob = time.time()
    print("processing ---> getting child property list for refactoring")
    
    propertyList = session.run(childProps1)
    
    print('-----------------')
    print("processing ---> starting refactoring to parent category")
    print ("%s %s" % ("using batch size: ", batchSize))
    print('-----------------')
 
    for property in propertyList:
        print("%s %s %s" % (property["pname"], "nodes:", property["ncount"]))
        t0 = time.time()
        btotal=0
        pname = (property["pname"])
        ncount = (property["ncount"])
        
        while True:
            result = session.run(indexRefactor1, {"pname": pname, "limit": batchSize})
            btotal = btotal + batchSize
            summary = result.consume()
            counters = summary.counters
            print(counters)
            
            if btotal < ncount:
                print('--next batch--')
                
            else:
                print('-----done-----')
                break
                    
        print(round((time.time() - t0)*1000,1), " ms elapsed time")
        ntotal = ntotal + ncount
        print ("%s %s" % ("------------------------------> total refactored nodes: ", ntotal))
        
                
except Exception as e:
    print('*** Got exception',e)
    if not isinstance(e, CypherError):
        print('*** Rolling back')
        session.rollback()
    else:
        print('*** Not rolling back')
    
finally:
    print('Done!')
    print(round((time.time() - tjob)/60,1), " minutes elapsed time")
# Out:
# processing query1 ---> getting child property list for refactoring
# -----------------
# processing query2 ---> starting refactoring to parent category
# using batch size:  2000
# -----------------
# Azerbaijan nodes: 3985
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1985}
# -----done-----
# 180.6  ms elapsed time
# ------------------------------> total refactored nodes:  3985
# Saint Kitts and Nevis nodes: 4161
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 161}
# -----done-----
# 157.5  ms elapsed time
# ------------------------------> total refactored nodes:  8146
# Egypt nodes: 3980
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1980}
# -----done-----
# 124.0  ms elapsed time
# ------------------------------> total refactored nodes:  12126
# Saudi Arabia nodes: 4131
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 131}
# -----done-----
# 133.8  ms elapsed time
# ------------------------------> total refactored nodes:  16257
# Virgin Islands, U.S. nodes: 3977
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1977}
# -----done-----
# 114.2  ms elapsed time
# ------------------------------> total refactored nodes:  20234
# Bouvet Island (Bouvetoya) nodes: 4029
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 29}
# -----done-----
# 131.3  ms elapsed time
# ------------------------------> total refactored nodes:  24263
# Turkmenistan nodes: 3899
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1899}
# -----done-----
# 116.5  ms elapsed time
# ------------------------------> total refactored nodes:  28162
# Christmas Island nodes: 3968
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1968}
# -----done-----
# 118.1  ms elapsed time
# ------------------------------> total refactored nodes:  32130
# Brazil nodes: 4002
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2}
# -----done-----
# 125.3  ms elapsed time
# ------------------------------> total refactored nodes:  36132
# Senegal nodes: 4067
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 67}
# -----done-----
# 140.6  ms elapsed time
# ------------------------------> total refactored nodes:  40199
# Kuwait nodes: 4117
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 117}
# -----done-----
# 130.6  ms elapsed time
# ------------------------------> total refactored nodes:  44316
# Austria nodes: 4052
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 52}
# -----done-----
# 140.3  ms elapsed time
# ------------------------------> total refactored nodes:  48368
# South Africa nodes: 4124
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 124}
# -----done-----
# 141.0  ms elapsed time
# ------------------------------> total refactored nodes:  52492
# Vietnam nodes: 4089
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 89}
# -----done-----
# 149.6  ms elapsed time
# ------------------------------> total refactored nodes:  56581
# Canada nodes: 4112
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 112}
# -----done-----
# 145.0  ms elapsed time
# ------------------------------> total refactored nodes:  60693
# Tokelau nodes: 4087
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 87}
# -----done-----
# 143.0  ms elapsed time
# ------------------------------> total refactored nodes:  64780
# Niue nodes: 4039
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 39}
# -----done-----
# 124.2  ms elapsed time
# ------------------------------> total refactored nodes:  68819
# Afghanistan nodes: 4151
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 151}
# -----done-----
# 130.7  ms elapsed time
# ------------------------------> total refactored nodes:  72970
# Saint Pierre and Miquelon nodes: 4007
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 7}
# -----done-----
# 123.9  ms elapsed time
# ------------------------------> total refactored nodes:  76977
# Eritrea nodes: 4202
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 202}
# -----done-----
# 130.1  ms elapsed time
# ------------------------------> total refactored nodes:  81179
# Western Sahara nodes: 4001
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1}
# -----done-----
# 134.2  ms elapsed time
# ------------------------------> total refactored nodes:  85180
# Lao People's Democratic Republic nodes: 4066
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 66}
# -----done-----
# 133.4  ms elapsed time
# ------------------------------> total refactored nodes:  89246
# Switzerland nodes: 4042
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 42}
# -----done-----
# 137.5  ms elapsed time
# ------------------------------> total refactored nodes:  93288
# Qatar nodes: 4086
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 86}
# -----done-----
# 128.6  ms elapsed time
# ------------------------------> total refactored nodes:  97374
# Slovenia nodes: 4141
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 141}
# -----done-----
# 123.0  ms elapsed time
# ------------------------------> total refactored nodes:  101515
# Taiwan nodes: 4003
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 3}
# -----done-----
# 127.2  ms elapsed time
# ------------------------------> total refactored nodes:  105518
# Australia nodes: 3987
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1987}
# -----done-----
# 119.0  ms elapsed time
# ------------------------------> total refactored nodes:  109505
# Svalbard & Jan Mayen Islands nodes: 4147
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 147}
# -----done-----
# 144.6  ms elapsed time
# ------------------------------> total refactored nodes:  113652
# Sao Tome and Principe nodes: 4022
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 22}
# -----done-----
# 137.0  ms elapsed time
# ------------------------------> total refactored nodes:  117674
# Mongolia nodes: 4074
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 74}
# -----done-----
# 134.0  ms elapsed time
# ------------------------------> total refactored nodes:  121748
# Reunion nodes: 3942
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1942}
# -----done-----
# 129.5  ms elapsed time
# ------------------------------> total refactored nodes:  125690
# Belarus nodes: 3994
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1994}
# -----done-----
# 125.2  ms elapsed time
# ------------------------------> total refactored nodes:  129684
# Central African Republic nodes: 4080
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 80}
# -----done-----
# 126.1  ms elapsed time
# ------------------------------> total refactored nodes:  133764
# Gibraltar nodes: 4106
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 106}
# -----done-----
# 132.8  ms elapsed time
# ------------------------------> total refactored nodes:  137870
# Uganda nodes: 4158
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 158}
# -----done-----
# 130.2  ms elapsed time
# ------------------------------> total refactored nodes:  142028
# Comoros nodes: 4148
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 148}
# -----done-----
# 128.3  ms elapsed time
# ------------------------------> total refactored nodes:  146176
# Tanzania nodes: 4116
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 116}
# -----done-----
# 125.5  ms elapsed time
# ------------------------------> total refactored nodes:  150292
# Macedonia nodes: 4122
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 122}
# -----done-----
# 132.3  ms elapsed time
# ------------------------------> total refactored nodes:  154414
# Panama nodes: 4075
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 75}
# -----done-----
# 125.7  ms elapsed time
# ------------------------------> total refactored nodes:  158489
# Republic of Korea nodes: 4097
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 97}
# -----done-----
# 141.1  ms elapsed time
# ------------------------------> total refactored nodes:  162586
# Pitcairn Islands nodes: 4123
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 123}
# -----done-----
# 162.4  ms elapsed time
# ------------------------------> total refactored nodes:  166709
# Costa Rica nodes: 4117
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 117}
# -----done-----
# 149.8  ms elapsed time
# ------------------------------> total refactored nodes:  170826
# Luxembourg nodes: 4255
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 255}
# -----done-----
# 144.7  ms elapsed time
# ------------------------------> total refactored nodes:  175081
# Belgium nodes: 4109
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 109}
# -----done-----
# 144.7  ms elapsed time
# ------------------------------> total refactored nodes:  179190
# French Guiana nodes: 4102
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 102}
# -----done-----
# 144.4  ms elapsed time
# ------------------------------> total refactored nodes:  183292
# French Polynesia nodes: 4146
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 146}
# -----done-----
# 139.9  ms elapsed time
# ------------------------------> total refactored nodes:  187438
# Norfolk Island nodes: 4131
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 131}
# -----done-----
# 141.9  ms elapsed time
# ------------------------------> total refactored nodes:  191569
# Timor-Leste nodes: 4013
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 13}
# -----done-----
# 149.0  ms elapsed time
# ------------------------------> total refactored nodes:  195582
# Heard Island and McDonald Islands nodes: 4049
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 49}
# -----done-----
# 137.1  ms elapsed time
# ------------------------------> total refactored nodes:  199631
# Romania nodes: 4159
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 159}
# -----done-----
# 147.5  ms elapsed time
# ------------------------------> total refactored nodes:  203790
# Brunei Darussalam nodes: 4033
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 33}
# -----done-----
# 165.9  ms elapsed time
# ------------------------------> total refactored nodes:  207823
# Saint Helena nodes: 4096
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 96}
# -----done-----
# 140.9  ms elapsed time
# ------------------------------> total refactored nodes:  211919
# Tunisia nodes: 4097
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 97}
# -----done-----
# 130.6  ms elapsed time
# ------------------------------> total refactored nodes:  216016
# Niger nodes: 4068
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 68}
# -----done-----
# 147.0  ms elapsed time
# ------------------------------> total refactored nodes:  220084
# Morocco nodes: 4081
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 81}
# -----done-----
# 137.6  ms elapsed time
# ------------------------------> total refactored nodes:  224165
# Mauritius nodes: 4113
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 113}
# -----done-----
# 153.2  ms elapsed time
# ------------------------------> total refactored nodes:  228278
# Congo nodes: 8309
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 309}
# -----done-----
# 214.4  ms elapsed time
# ------------------------------> total refactored nodes:  236587
# Gambia nodes: 4125
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 125}
# -----done-----
# 136.4  ms elapsed time
# ------------------------------> total refactored nodes:  240712
# Guam nodes: 4115
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 115}
# -----done-----
# 159.1  ms elapsed time
# ------------------------------> total refactored nodes:  244827
# Thailand nodes: 4113
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 113}
# -----done-----
# 151.1  ms elapsed time
# ------------------------------> total refactored nodes:  248940
# Ghana nodes: 4099
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 99}
# -----done-----
# 141.9  ms elapsed time
# ------------------------------> total refactored nodes:  253039
# Monaco nodes: 3984
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1984}
# -----done-----
# 139.6  ms elapsed time
# ------------------------------> total refactored nodes:  257023
# Argentina nodes: 4058
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 58}
# -----done-----
# 142.2  ms elapsed time
# ------------------------------> total refactored nodes:  261081
# Faroe Islands nodes: 4187
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 187}
# -----done-----
# 163.4  ms elapsed time
# ------------------------------> total refactored nodes:  265268
# Solomon Islands nodes: 4058
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 58}
# -----done-----
# 145.1  ms elapsed time
# ------------------------------> total refactored nodes:  269326
# Aruba nodes: 4159
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 159}
# -----done-----
# 154.0  ms elapsed time
# ------------------------------> total refactored nodes:  273485
# Malawi nodes: 4087
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 87}
# -----done-----
# 142.1  ms elapsed time
# ------------------------------> total refactored nodes:  277572
# Sudan nodes: 4155
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 155}
# -----done-----
# 135.3  ms elapsed time
# ------------------------------> total refactored nodes:  281727
# Saint Martin nodes: 4033
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 33}
# -----done-----
# 166.8  ms elapsed time
# ------------------------------> total refactored nodes:  285760
# Papua New Guinea nodes: 4188
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 188}
# -----done-----
# 147.6  ms elapsed time
# ------------------------------> total refactored nodes:  289948
# Lesotho nodes: 4040
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 40}
# -----done-----
# 137.1  ms elapsed time
# ------------------------------> total refactored nodes:  293988
# Mali nodes: 4088
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 88}
# -----done-----
# 142.0  ms elapsed time
# ------------------------------> total refactored nodes:  298076
# Antarctica (the territory South of 60 deg S) nodes: 4032
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 32}
# -----done-----
# 159.0  ms elapsed time
# ------------------------------> total refactored nodes:  302108
# Tonga nodes: 4096
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 96}
# -----done-----
# 149.5  ms elapsed time
# ------------------------------> total refactored nodes:  306204
# Saint Barthelemy nodes: 3992
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1992}
# -----done-----
# 134.6  ms elapsed time
# ------------------------------> total refactored nodes:  310196
# Dominica nodes: 4053
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 53}
# -----done-----
# 165.9  ms elapsed time
# ------------------------------> total refactored nodes:  314249
# Cape Verde nodes: 4114
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 114}
# -----done-----
# 129.8  ms elapsed time
# ------------------------------> total refactored nodes:  318363
# Peru nodes: 3994
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1994}
# -----done-----
# 140.1  ms elapsed time
# ------------------------------> total refactored nodes:  322357
# Honduras nodes: 4099
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 99}
# -----done-----
# 148.5  ms elapsed time
# ------------------------------> total refactored nodes:  326456
# Virgin Islands, British nodes: 4014
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 14}
# -----done-----
# 144.2  ms elapsed time
# ------------------------------> total refactored nodes:  330470
# Zimbabwe nodes: 4118
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 118}
# -----done-----
# 138.8  ms elapsed time
# ------------------------------> total refactored nodes:  334588
# Syrian Arab Republic nodes: 4083
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 83}
# -----done-----
# 133.5  ms elapsed time
# ------------------------------> total refactored nodes:  338671
# Myanmar nodes: 4063
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 63}
# -----done-----
# 133.8  ms elapsed time
# ------------------------------> total refactored nodes:  342734
# Kiribati nodes: 4079
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 79}
# -----done-----
# 146.9  ms elapsed time
# ------------------------------> total refactored nodes:  346813
# Maldives nodes: 4028
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 28}
# -----done-----
# 131.4  ms elapsed time
# ------------------------------> total refactored nodes:  350841
# Seychelles nodes: 4191
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 191}
# -----done-----
# 154.7  ms elapsed time
# ------------------------------> total refactored nodes:  355032
# Vanuatu nodes: 4126
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 126}
# -----done-----
# 151.1  ms elapsed time
# ------------------------------> total refactored nodes:  359158
# Yemen nodes: 4103
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 103}
# -----done-----
# 129.4  ms elapsed time
# ------------------------------> total refactored nodes:  363261
# Bahamas nodes: 4070
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 70}
# -----done-----
# 146.3  ms elapsed time
# ------------------------------> total refactored nodes:  367331
# Norway nodes: 4120
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 120}
# -----done-----
# 137.0  ms elapsed time
# ------------------------------> total refactored nodes:  371451
# Guadeloupe nodes: 4098
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 98}
# -----done-----
# 156.7  ms elapsed time
# ------------------------------> total refactored nodes:  375549
# Montserrat nodes: 4062
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 62}
# -----done-----
# 145.8  ms elapsed time
# ------------------------------> total refactored nodes:  379611
# United States Minor Outlying Islands nodes: 4143
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 143}
# -----done-----
# 166.3  ms elapsed time
# ------------------------------> total refactored nodes:  383754
# Greenland nodes: 4103
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 103}
# -----done-----
# 143.3  ms elapsed time
# ------------------------------> total refactored nodes:  387857
# Madagascar nodes: 4040
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 40}
# -----done-----
# 148.7  ms elapsed time
# ------------------------------> total refactored nodes:  391897
# Guatemala nodes: 4202
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 202}
# -----done-----
# 171.2  ms elapsed time
# ------------------------------> total refactored nodes:  396099
# San Marino nodes: 4004
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 4}
# -----done-----
# 135.6  ms elapsed time
# ------------------------------> total refactored nodes:  400103
# Malta nodes: 3947
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1947}
# -----done-----
# 149.9  ms elapsed time
# ------------------------------> total refactored nodes:  404050
# Nigeria nodes: 4110
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 110}
# -----done-----
# 153.4  ms elapsed time
# ------------------------------> total refactored nodes:  408160
# Germany nodes: 4153
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 153}
# -----done-----
# 147.9  ms elapsed time
# ------------------------------> total refactored nodes:  412313
# France nodes: 4187
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 187}
# -----done-----
# 138.4  ms elapsed time
# ------------------------------> total refactored nodes:  416500
# New Caledonia nodes: 4109
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 109}
# -----done-----
# 139.9  ms elapsed time
# ------------------------------> total refactored nodes:  420609
# Ireland nodes: 3953
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1953}
# -----done-----
# 127.8  ms elapsed time
# ------------------------------> total refactored nodes:  424562
# Northern Mariana Islands nodes: 4114
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 114}
# -----done-----
# 150.9  ms elapsed time
# ------------------------------> total refactored nodes:  428676
# Cyprus nodes: 4073
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 73}
# -----done-----
# 158.8  ms elapsed time
# ------------------------------> total refactored nodes:  432749
# Italy nodes: 4082
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 82}
# -----done-----
# 143.2  ms elapsed time
# ------------------------------> total refactored nodes:  436831
# Venezuela nodes: 4141
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 141}
# -----done-----
# 148.2  ms elapsed time
# ------------------------------> total refactored nodes:  440972
# Kenya nodes: 4149
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 149}
# -----done-----
# 142.3  ms elapsed time
# ------------------------------> total refactored nodes:  445121
# Pakistan nodes: 3954
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1954}
# -----done-----
# 133.5  ms elapsed time
# ------------------------------> total refactored nodes:  449075
# Netherlands Antilles nodes: 4166
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 166}
# -----done-----
# 135.4  ms elapsed time
# ------------------------------> total refactored nodes:  453241
# Bhutan nodes: 4080
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 80}
# -----done-----
# 140.9  ms elapsed time
# ------------------------------> total refactored nodes:  457321
# Bangladesh nodes: 4097
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 97}
# -----done-----
# 151.8  ms elapsed time
# ------------------------------> total refactored nodes:  461418
# Czech Republic nodes: 3961
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1961}
# -----done-----
# 125.8  ms elapsed time
# ------------------------------> total refactored nodes:  465379
# Palau nodes: 4037
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 37}
# -----done-----
# 154.1  ms elapsed time
# ------------------------------> total refactored nodes:  469416
# Benin nodes: 4026
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 26}
# -----done-----
# 141.3  ms elapsed time
# ------------------------------> total refactored nodes:  473442
# Marshall Islands nodes: 4009
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 9}
# -----done-----
# 157.6  ms elapsed time
# ------------------------------> total refactored nodes:  477451
# Falkland Islands (Malvinas) nodes: 4071
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 71}
# -----done-----
# 150.5  ms elapsed time
# ------------------------------> total refactored nodes:  481522
# Martinique nodes: 4117
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 117}
# -----done-----
# 140.6  ms elapsed time
# ------------------------------> total refactored nodes:  485639
# Democratic People's Republic of Korea nodes: 3924
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1924}
# -----done-----
# 159.8  ms elapsed time
# ------------------------------> total refactored nodes:  489563
# Poland nodes: 4135
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 135}
# -----done-----
# 141.3  ms elapsed time
# ------------------------------> total refactored nodes:  493698
# Holy See (Vatican City State) nodes: 3964
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1964}
# -----done-----
# 138.9  ms elapsed time
# ------------------------------> total refactored nodes:  497662
# Estonia nodes: 4061
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 61}
# -----done-----
# 140.8  ms elapsed time
# ------------------------------> total refactored nodes:  501723
# Uruguay nodes: 4126
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 126}
# -----done-----
# 152.0  ms elapsed time
# ------------------------------> total refactored nodes:  505849
# Burundi nodes: 4199
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 199}
# -----done-----
# 149.2  ms elapsed time
# ------------------------------> total refactored nodes:  510048
# Ecuador nodes: 4160
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 160}
# -----done-----
# 130.6  ms elapsed time
# ------------------------------> total refactored nodes:  514208
# Ukraine nodes: 4111
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 111}
# -----done-----
# 130.9  ms elapsed time
# ------------------------------> total refactored nodes:  518319
# Cayman Islands nodes: 4041
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 41}
# -----done-----
# 142.2  ms elapsed time
# ------------------------------> total refactored nodes:  522360
# Haiti nodes: 4106
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 106}
# -----done-----
# 139.1  ms elapsed time
# ------------------------------> total refactored nodes:  526466
# Dominican Republic nodes: 4127
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 127}
# -----done-----
# 153.0  ms elapsed time
# ------------------------------> total refactored nodes:  530593
# Denmark nodes: 4120
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 120}
# -----done-----
# 147.3  ms elapsed time
# ------------------------------> total refactored nodes:  534713
# Guinea-Bissau nodes: 4077
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 77}
# -----done-----
# 139.3  ms elapsed time
# ------------------------------> total refactored nodes:  538790
# Saint Lucia nodes: 4012
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 12}
# -----done-----
# 139.4  ms elapsed time
# ------------------------------> total refactored nodes:  542802
# Sri Lanka nodes: 4025
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 25}
# -----done-----
# 125.4  ms elapsed time
# ------------------------------> total refactored nodes:  546827
# Guernsey nodes: 4007
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 7}
# -----done-----
# 125.5  ms elapsed time
# ------------------------------> total refactored nodes:  550834
# China nodes: 4188
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 188}
# -----done-----
# 151.3  ms elapsed time
# ------------------------------> total refactored nodes:  555022
# South Georgia and the South Sandwich Islands nodes: 4175
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 175}
# -----done-----
# 155.6  ms elapsed time
# ------------------------------> total refactored nodes:  559197
# Isle of Man nodes: 4123
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 123}
# -----done-----
# 136.6  ms elapsed time
# ------------------------------> total refactored nodes:  563320
# Zambia nodes: 4012
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 12}
# -----done-----
# 145.4  ms elapsed time
# ------------------------------> total refactored nodes:  567332
# Grenada nodes: 4146
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 146}
# -----done-----
# 145.8  ms elapsed time
# ------------------------------> total refactored nodes:  571478
# Puerto Rico nodes: 4187
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 187}
# -----done-----
# 135.6  ms elapsed time
# ------------------------------> total refactored nodes:  575665
# Kazakhstan nodes: 4103
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 103}
# -----done-----
# 137.3  ms elapsed time
# ------------------------------> total refactored nodes:  579768
# Turks and Caicos Islands nodes: 4059
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 59}
# -----done-----
# 167.3  ms elapsed time
# ------------------------------> total refactored nodes:  583827
# Liberia nodes: 4091
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 91}
# -----done-----
# 147.3  ms elapsed time
# ------------------------------> total refactored nodes:  587918
# El Salvador nodes: 4161
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 161}
# -----done-----
# 152.2  ms elapsed time
# ------------------------------> total refactored nodes:  592079
# Bahrain nodes: 3983
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1983}
# -----done-----
# 280.6  ms elapsed time
# ------------------------------> total refactored nodes:  596062
# Suriname nodes: 3973
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1973}
# -----done-----
# 133.0  ms elapsed time
# ------------------------------> total refactored nodes:  600035
# Greece nodes: 4064
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 64}
# -----done-----
# 140.7  ms elapsed time
# ------------------------------> total refactored nodes:  604099
# Liechtenstein nodes: 4097
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 97}
# -----done-----
# 147.3  ms elapsed time
# ------------------------------> total refactored nodes:  608196
# Portugal nodes: 4026
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 26}
# -----done-----
# 133.4  ms elapsed time
# ------------------------------> total refactored nodes:  612222
# Bosnia and Herzegovina nodes: 4127
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 127}
# -----done-----
# 150.3  ms elapsed time
# ------------------------------> total refactored nodes:  616349
# Bulgaria nodes: 4078
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 78}
# -----done-----
# 134.7  ms elapsed time
# ------------------------------> total refactored nodes:  620427
# Somalia nodes: 4193
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 193}
# -----done-----
# 151.2  ms elapsed time
# ------------------------------> total refactored nodes:  624620
# Sweden nodes: 4108
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 108}
# -----done-----
# 143.2  ms elapsed time
# ------------------------------> total refactored nodes:  628728
# Iceland nodes: 4072
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 72}
# -----done-----
# 141.9  ms elapsed time
# ------------------------------> total refactored nodes:  632800
# United Arab Emirates nodes: 4087
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 87}
# -----done-----
# 142.7  ms elapsed time
# ------------------------------> total refactored nodes:  636887
# Netherlands nodes: 4096
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 96}
# -----done-----
# 137.2  ms elapsed time
# ------------------------------> total refactored nodes:  640983
# Ethiopia nodes: 4110
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 110}
# -----done-----
# 138.5  ms elapsed time
# ------------------------------> total refactored nodes:  645093
# Philippines nodes: 4105
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 105}
# -----done-----
# 162.4  ms elapsed time
# ------------------------------> total refactored nodes:  649198
# Colombia nodes: 4054
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 54}
# -----done-----
# 148.8  ms elapsed time
# ------------------------------> total refactored nodes:  653252
# Oman nodes: 4034
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 34}
# -----done-----
# 141.8  ms elapsed time
# ------------------------------> total refactored nodes:  657286
# Swaziland nodes: 4030
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 30}
# -----done-----
# 137.8  ms elapsed time
# ------------------------------> total refactored nodes:  661316
# Turkey nodes: 4181
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 181}
# -----done-----
# 143.3  ms elapsed time
# ------------------------------> total refactored nodes:  665497
# British Indian Ocean Territory (Chagos Archipelago) nodes: 4073
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 73}
# -----done-----
# 144.6  ms elapsed time
# ------------------------------> total refactored nodes:  669570
# Samoa nodes: 4145
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 145}
# -----done-----
# 132.9  ms elapsed time
# ------------------------------> total refactored nodes:  673715
# Wallis and Futuna nodes: 4076
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 76}
# -----done-----
# 153.1  ms elapsed time
# ------------------------------> total refactored nodes:  677791
# Lithuania nodes: 4088
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 88}
# -----done-----
# 132.0  ms elapsed time
# ------------------------------> total refactored nodes:  681879
# Trinidad and Tobago nodes: 4079
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 79}
# -----done-----
# 158.3  ms elapsed time
# ------------------------------> total refactored nodes:  685958
# India nodes: 4094
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 94}
# -----done-----
# 135.7  ms elapsed time
# ------------------------------> total refactored nodes:  690052
# Anguilla nodes: 4067
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 67}
# -----done-----
# 131.6  ms elapsed time
# ------------------------------> total refactored nodes:  694119
# Libyan Arab Jamahiriya nodes: 4053
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 53}
# -----done-----
# 133.4  ms elapsed time
# ------------------------------> total refactored nodes:  698172
# Djibouti nodes: 4085
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 85}
# -----done-----
# 132.2  ms elapsed time
# ------------------------------> total refactored nodes:  702257
# Nepal nodes: 4034
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 34}
# -----done-----
# 127.9  ms elapsed time
# ------------------------------> total refactored nodes:  706291
# French Southern Territories nodes: 4088
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 88}
# -----done-----
# 132.8  ms elapsed time
# ------------------------------> total refactored nodes:  710379
# Cook Islands nodes: 3897
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1897}
# -----done-----
# 136.1  ms elapsed time
# ------------------------------> total refactored nodes:  714276
# Latvia nodes: 4088
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 88}
# -----done-----
# 148.6  ms elapsed time
# ------------------------------> total refactored nodes:  718364
# Hungary nodes: 4041
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 41}
# -----done-----
# 147.2  ms elapsed time
# ------------------------------> total refactored nodes:  722405
# Antigua and Barbuda nodes: 4038
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 38}
# -----done-----
# 144.1  ms elapsed time
# ------------------------------> total refactored nodes:  726443
# Chad nodes: 4185
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 185}
# -----done-----
# 134.2  ms elapsed time
# ------------------------------> total refactored nodes:  730628
# Algeria nodes: 4218
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 218}
# -----done-----
# 128.3  ms elapsed time
# ------------------------------> total refactored nodes:  734846
# Jordan nodes: 4135
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 135}
# -----done-----
# 130.5  ms elapsed time
# ------------------------------> total refactored nodes:  738981
# Gabon nodes: 4035
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 35}
# -----done-----
# 148.6  ms elapsed time
# ------------------------------> total refactored nodes:  743016
# Paraguay nodes: 4179
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 179}
# -----done-----
# 146.3  ms elapsed time
# ------------------------------> total refactored nodes:  747195
# Lebanon nodes: 4071
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 71}
# -----done-----
# 151.3  ms elapsed time
# ------------------------------> total refactored nodes:  751266
# Togo nodes: 4111
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 111}
# -----done-----
# 140.3  ms elapsed time
# ------------------------------> total refactored nodes:  755377
# Fiji nodes: 4229
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 229}
# -----done-----
# 143.3  ms elapsed time
# ------------------------------> total refactored nodes:  759606
# Russian Federation nodes: 4162
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 162}
# -----done-----
# 138.1  ms elapsed time
# ------------------------------> total refactored nodes:  763768
# Sierra Leone nodes: 4024
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 24}
# -----done-----
# 155.7  ms elapsed time
# ------------------------------> total refactored nodes:  767792
# Mauritania nodes: 4059
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 59}
# -----done-----
# 132.8  ms elapsed time
# ------------------------------> total refactored nodes:  771851
# Macao nodes: 3997
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1997}
# -----done-----
# 124.1  ms elapsed time
# ------------------------------> total refactored nodes:  775848
# American Samoa nodes: 4100
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 100}
# -----done-----
# 136.3  ms elapsed time
# ------------------------------> total refactored nodes:  779948
# Slovakia (Slovak Republic) nodes: 4030
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 30}
# -----done-----
# 135.1  ms elapsed time
# ------------------------------> total refactored nodes:  783978
# Uzbekistan nodes: 4107
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 107}
# -----done-----
# 133.1  ms elapsed time
# ------------------------------> total refactored nodes:  788085
# Guyana nodes: 4013
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 13}
# -----done-----
# 128.5  ms elapsed time
# ------------------------------> total refactored nodes:  792098
# Saint Vincent and the Grenadines nodes: 3989
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1989}
# -----done-----
# 126.4  ms elapsed time
# ------------------------------> total refactored nodes:  796087
# Tuvalu nodes: 4171
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 171}
# -----done-----
# 129.5  ms elapsed time
# ------------------------------> total refactored nodes:  800258
# Nauru nodes: 4005
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 5}
# -----done-----
# 133.1  ms elapsed time
# ------------------------------> total refactored nodes:  804263
# Spain nodes: 3941
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1941}
# -----done-----
# 141.5  ms elapsed time
# ------------------------------> total refactored nodes:  808204
# Albania nodes: 4094
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 94}
# -----done-----
# 156.3  ms elapsed time
# ------------------------------> total refactored nodes:  812298
# Namibia nodes: 4059
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 59}
# -----done-----
# 142.2  ms elapsed time
# ------------------------------> total refactored nodes:  816357
# Mexico nodes: 4146
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 146}
# -----done-----
# 134.6  ms elapsed time
# ------------------------------> total refactored nodes:  820503
# Serbia nodes: 4007
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 7}
# -----done-----
# 131.1  ms elapsed time
# ------------------------------> total refactored nodes:  824510
# Cameroon nodes: 4104
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 104}
# -----done-----
# 133.4  ms elapsed time
# ------------------------------> total refactored nodes:  828614
# Iraq nodes: 3975
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1975}
# -----done-----
# 122.1  ms elapsed time
# ------------------------------> total refactored nodes:  832589
# Guinea nodes: 3973
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1973}
# -----done-----
# 116.0  ms elapsed time
# ------------------------------> total refactored nodes:  836562
# New Zealand nodes: 4032
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 32}
# -----done-----
# 146.6  ms elapsed time
# ------------------------------> total refactored nodes:  840594
# Chile nodes: 4087
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 87}
# -----done-----
# 144.3  ms elapsed time
# ------------------------------> total refactored nodes:  844681
# Belize nodes: 4189
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 189}
# -----done-----
# 145.1  ms elapsed time
# ------------------------------> total refactored nodes:  848870
# Armenia nodes: 4142
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 142}
# -----done-----
# 129.6  ms elapsed time
# ------------------------------> total refactored nodes:  853012
# Botswana nodes: 4074
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 74}
# -----done-----
# 148.0  ms elapsed time
# ------------------------------> total refactored nodes:  857086
# Israel nodes: 4129
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 129}
# -----done-----
# 133.1  ms elapsed time
# ------------------------------> total refactored nodes:  861215
# Croatia nodes: 4031
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 31}
# -----done-----
# 171.6  ms elapsed time
# ------------------------------> total refactored nodes:  865246
# Hong Kong nodes: 4159
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 159}
# -----done-----
# 139.4  ms elapsed time
# ------------------------------> total refactored nodes:  869405
# United States of America nodes: 4122
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 122}
# -----done-----
# 139.4  ms elapsed time
# ------------------------------> total refactored nodes:  873527
# Cocos (Keeling) Islands nodes: 3977
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1977}
# -----done-----
# 133.0  ms elapsed time
# ------------------------------> total refactored nodes:  877504
# Cuba nodes: 4046
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 46}
# -----done-----
# 132.1  ms elapsed time
# ------------------------------> total refactored nodes:  881550
# Rwanda nodes: 4023
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 23}
# -----done-----
# 131.0  ms elapsed time
# ------------------------------> total refactored nodes:  885573
# Malaysia nodes: 4099
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 99}
# -----done-----
# 124.6  ms elapsed time
# ------------------------------> total refactored nodes:  889672
# United Kingdom nodes: 4061
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 61}
# -----done-----
# 141.6  ms elapsed time
# ------------------------------> total refactored nodes:  893733
# Jersey nodes: 4099
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 99}
# -----done-----
# 128.0  ms elapsed time
# ------------------------------> total refactored nodes:  897832
# Singapore nodes: 4085
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 85}
# -----done-----
# 129.8  ms elapsed time
# ------------------------------> total refactored nodes:  901917
# Burkina Faso nodes: 4106
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 106}
# -----done-----
# 136.1  ms elapsed time
# ------------------------------> total refactored nodes:  906023
# Cambodia nodes: 4119
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 119}
# -----done-----
# 156.6  ms elapsed time
# ------------------------------> total refactored nodes:  910142
# Equatorial Guinea nodes: 4080
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 80}
# -----done-----
# 142.7  ms elapsed time
# ------------------------------> total refactored nodes:  914222
# Mozambique nodes: 4015
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 15}
# -----done-----
# 148.7  ms elapsed time
# ------------------------------> total refactored nodes:  918237
# Bermuda nodes: 4122
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 122}
# -----done-----
# 127.4  ms elapsed time
# ------------------------------> total refactored nodes:  922359
# Palestinian Territory nodes: 4018
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 18}
# -----done-----
# 145.0  ms elapsed time
# ------------------------------> total refactored nodes:  926377
# Montenegro nodes: 4051
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 51}
# -----done-----
# 139.9  ms elapsed time
# ------------------------------> total refactored nodes:  930428
# Georgia nodes: 4105
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 105}
# -----done-----
# 129.7  ms elapsed time
# ------------------------------> total refactored nodes:  934533
# Japan nodes: 4077
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 77}
# -----done-----
# 129.4  ms elapsed time
# ------------------------------> total refactored nodes:  938610
# Kyrgyz Republic nodes: 4198
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 198}
# -----done-----
# 157.9  ms elapsed time
# ------------------------------> total refactored nodes:  942808
# Mayotte nodes: 3978
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1978}
# -----done-----
# 137.2  ms elapsed time
# ------------------------------> total refactored nodes:  946786
# Finland nodes: 4122
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 122}
# -----done-----
# 152.4  ms elapsed time
# ------------------------------> total refactored nodes:  950908
# Cote d'Ivoire nodes: 4171
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 171}
# -----done-----
# 166.1  ms elapsed time
# ------------------------------> total refactored nodes:  955079
# Moldova nodes: 4114
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 114}
# -----done-----
# 137.4  ms elapsed time
# ------------------------------> total refactored nodes:  959193
# Tajikistan nodes: 4123
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 123}
# -----done-----
# 133.1  ms elapsed time
# ------------------------------> total refactored nodes:  963316
# Andorra nodes: 4099
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 99}
# -----done-----
# 132.2  ms elapsed time
# ------------------------------> total refactored nodes:  967415
# Nicaragua nodes: 4091
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 91}
# -----done-----
# 137.0  ms elapsed time
# ------------------------------> total refactored nodes:  971506
# Barbados nodes: 4124
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 124}
# -----done-----
# 148.4  ms elapsed time
# ------------------------------> total refactored nodes:  975630
# Micronesia nodes: 4063
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 63}
# -----done-----
# 138.3  ms elapsed time
# ------------------------------> total refactored nodes:  979693
# Indonesia nodes: 4031
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 31}
# -----done-----
# 145.8  ms elapsed time
# ------------------------------> total refactored nodes:  983724
# Jamaica nodes: 4197
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 197}
# -----done-----
# 149.2  ms elapsed time
# ------------------------------> total refactored nodes:  987921
# Iran nodes: 3963
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 1963}
# -----done-----
# 126.0  ms elapsed time
# ------------------------------> total refactored nodes:  991884
# Bolivia nodes: 4076
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 76}
# -----done-----
# 139.8  ms elapsed time
# ------------------------------> total refactored nodes:  995960
# Angola nodes: 4040
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 2000}
# --next batch--
# {'relationships_created': 40}
# -----done-----
# 137.3  ms elapsed time
# ------------------------------> total refactored nodes:  1000000
# Done!
# 0.6  minutes elapsed time
